# %%
# Segundo challenge

# Variables
nombre = 'thiago'
apellido ='Villanueva'
edad = 18 
ciudad = 'lambare asuncion'


# Texto


print('Mi nombre es',nombre, apellido,'Recido de', ciudad, 'mi edad es ', edad)
# Out:
# Mi nombre es thiago Villanueva Recido de lambare asuncion mi edad es  18

# %%
# challenge 3

# Suma de venta
cantidad_de_manzanas= 14
cantidad_de_naranjas= 12
cantidad_de_frutas=cantidad_de_manzanas+cantidad_de_naranjas
print('frutas de suma 26'),cantidad_de_frutas
# suma total

#totaldefrutas = 26

# frutas vendidas


frutas_vendidas = 12
cantidad_de_frutas = cantidad_de_frutas - frutas_vendidas
print('Frutas restantes:', cantidad_de_frutas)
# Out:
# frutas de suma 26
# Frutas restantes: 14

# %%
# challenge 4
# Asignar los nombres y apellidos

nombre = 'denilson'
apellido = 'recalde'
espacio = " "
# imprimir el codigo

print('mi compañero se llama' , nombre + espacio + apellido)
# Out:
# mi compañero se llama denilson recalde

# %%
# Utilizacion de input y int

# variables

numero1=int(input('dime un numero'))
numero2=int(input('dime otro numero'))

# imprimir cantidad de pedido

print('la suma de los numeros es',numero1+numero2)
# Out:
# la suma de los numeros es 123

# %%
# challenge

# Aprendiendo a usar def: DEFINICION DE VARIABLES

def crear_un_avion():
    print('el avion estara en unos minutuos')
    print('el avion estara en unos minutos')

# ahora dar la orden para que inicie la accion

crear_un_avion()
crear_un_avion()    
crear_un_avion()
# Out:
# el avion estara en unos minutuos
# el avion estara en unos minutos
# el avion estara en unos minutuos
# el avion estara en unos minutos
# el avion estara en unos minutuos
# el avion estara en unos minutos

# %%
def articulo_a_comprar(x, y, z):
    print("Buenas Tardes, que articulo necesitaria")
    print(f'Necesito una {x} de {y} para arreglar mi {z}')
    print('-----------------------------------------------')

especif1= input('Defina el articulo de su eleccion')
especif2= input('Especifique la medida o tipo')
especif3= input('Çuentenos para que lo necesita')

articulo_a_comprar(especif1, especif2, especif3)

articulo_a_comprar('LLave', '3/4', 'moto')
articulo_a_comprar('Lija', '100', 'puerta')
articulo_a_comprar('pintura', 'exterior', 'fachada')

# %%
def articulo_a_comprar(articulo1,articulo2,articulo3):
    print('buenas, que articulo quisiera?')
    print (f'necesitas un {articulo1}) de {articulo2} que color le estaria gustando?{articulo3}') 
articulo1= input('Que articulo tecnologico necesita?')
articulo2= input('Que marca quiere?')
articulo3= input('Que color desea?')


articulo_a_comprar('iphone'),(('Samsung')),(('Xiaomi'))
articulo_a_comprar('rojo'),('azul'),('verde')
articulo_a_comprar('Grande'),('mediano)',('chico'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 9
#       5 articulo2= input('Que marca quiere?')
#       6 articulo3= input('Que color desea?')
# ----> 9 articulo_a_comprar(('iphone')),(('Samsung')),(('Xiaomi'))
#      10 articulo_a_comprar('rojo'),('azul'),('verde')
#      11 articulo_a_comprar('Grande'),('mediano)',('chico'))
#
# TypeError: articulo_a_comprar() missing 2 required positional arguments: 'articulo2' and 'articulo3'
