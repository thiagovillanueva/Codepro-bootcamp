# %%
# Definir una variable
# Crear una funcion Imprimir_una_palabra()
    #Impriir la variable palabra

#Llamar a la funcion

palabra = "hola"
def imprimir_palabra():
    print(palabra)
imprimir_palabra()
# Out:
# hola

# %%
# Pedir al usuario que ingrese una palabra
palabra_buscada1 = input('ingresa un palabra')
print (f'Esta palabra es la que busco',{palabra_buscada1})
palabra_ingresada = list  (palabra_buscada1)

for i in range(3):
    palabra_ingresada.append(palabra_buscada1)
    print(palabra_ingresada)

# %% [markdown]
# ## Challenge 6 🤺 - 20m
#
# Dada la lista de ejemplo:
#
# lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]
#
# `Crear una función` que `imprima` una grilla (lista de listas), `una línea` por cada lista dentro de la lista principal.
#
# Ejemplo del resultado esperado:
#
# ```
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']
# ```

# %%
def imprimir_listaa(lista):
    for fila in lista:
        print(fila)
lista = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]
imprimir_listaa(lista)
# Out:
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']

# %%
def imprimir_lista2(lista):
    for fila in lista2:
        print(fila)
    
lista2 = [['h', 'o', 'l', 'i', 's'], ['h', 'e', 'l', 'l', 'o'], ['h', 'a', 'l', 'l', 'o']]
imprimir_lista2(lista2)
# Out:
# ['h', 'o', 'l', 'i', 's']
# ['h', 'e', 'l', 'l', 'o']
# ['h', 'a', 'l', 'l', 'o']

# %%
# crear lista vacia de letras
letra_verificadas = []
cantidad_letras = 5
palabra_secreta = 'salto'
palabra_ingresada = '

def verificador_palabras(palabra_ingresada):
    for i in range(cantidad_letras):
        las_palabras_son_iguales = palabra_ingresada[i] == palabra_secreta[i] # True o false
        la_letra_exixste_en_la_palabra = palabra_ingresada[i] in palabra_secreta
    
        if las_palabras_son_iguales:
            letra_verificadas.append(f"([palabra_ingresada[i]])")
        elif la_letra_exixste_en_la_palabra:
            letra_verificadas.append(f"([palabra_ingresada[i]])")
        else:
            letra_verificadas.append(palabra_ingresada[i])

verificador_palabras
